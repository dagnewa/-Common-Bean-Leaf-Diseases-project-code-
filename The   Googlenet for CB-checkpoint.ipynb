# %%
import os

from platform import python_version
import warnings
import time
import datetime as dt
from sklearn.metrics import classification_report, confusion_matrix
import multiprocessing as mp
import shutil

import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.applications.inception_v3 import InceptionV3
#from keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.inception_v3 import preprocess_input
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *

import pandas as pd
import numpy as np
import seaborn as sn

from PIL import Image
import xml.etree.ElementTree as ET
import psutil
import random

warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
epochs = 100
batch_size = 32
#testsplit = .2
targetx = 150
targety = 150
learning_rate = 0.0001
classes = 4
seed = random.randint(1, 1000)
data_dir = "C:\\Users\\dagne\\Desktop\\common_bean_datasetv\\train"
data_dir1 = "C:\\Users\\dagne\\Desktop\\common_bean_datasetv\\valid"

# %%
datagen = ImageDataGenerator(
        shear_range=0.1,
        #rescale=1./255,
        zoom_range=0.1,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        preprocessing_function=preprocess_input
)


train_generator = datagen.flow_from_directory(
        data_dir,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=seed
        
)

validation_generator = datagen.flow_from_directory(
        data_dir1,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False,
        seed=seed       
)
# Out:
# Found 1235 images belonging to 4 classes.
# Found 268 images belonging to 4 classes.

# %%
checkpoint = ModelCheckpoint('googlenet2.h5',
                             monitor='val_acc',
                             save_best_only=True,
                             verbose=1,
                             mode='auto',
                             save_weights_only=False,
                             period=1)

#tensorboard = TensorBoard(log_dir="./logs-"+dt.datetime.now().strftime("%m%d%Y%H%M%S"),
                           # histogram_freq=0,
                            #batch_size=batch_size,
                            #write_graph=False,
                            #update_freq='epoch')

def epoch_end(epoch, logs):
    message = "End of epoch "+str(epoch)+". Learning rate: "+str(K.eval(model.optimizer.lr))
    os.system('echo '+message)

def epoch_begin(epoch, logs):
    print("Learning rate: ", K.eval(model.optimizer.lr))
    
def train_begin(logs):
    os.system("echo Beginning training")

earlystop = EarlyStopping(monitor='val_accuracy',
                          min_delta=.0001,
                          patience=50,
                          verbose=1,
                          mode='auto',
                          baseline=None,
                          restore_best_weights=True)

reducelr = ReduceLROnPlateau(monitor='val_accuracy',
                             factor=np.sqrt(.1),
                             patience=5,
                             verbose=1,
                             mode='auto',
                             min_delta=.0001,
                             cooldown=0,
                             min_lr=0.0000001)

lambdacb = LambdaCallback(on_epoch_begin=epoch_begin,
                          on_epoch_end=epoch_end,
                          on_batch_begin=None,
                          on_batch_end=None,
                          on_train_begin=train_begin,
                          on_train_end=None)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of samples seen.

# %%
base_model = InceptionV3(include_top=False, weights='imagenet', input_shape=(targetx, targety, 3))
for layer in base_model.layers:
    layer.trainable = False
x = base_model.output
x = GlobalAveragePooling2D()(x)
#x = Dropout(0.85)(x)
x = BatchNormalization()(x)
x = Dense(1280, activation='relu',  kernel_initializer=glorot_uniform(seed), bias_initializer='zeros')(x)
x = Dropout(0.8)(x)
x = BatchNormalization()(x)
predictions = Dense(classes, activation='softmax', kernel_initializer='random_uniform', bias_initializer='zeros')(x)

model = Model(inputs=base_model.input, outputs=predictions)
optimizer = Adam(lr=learning_rate)
loss = "categorical_crossentropy"



model.compile(optimizer=optimizer,
              loss=loss,
              metrics=["accuracy"])

model.summary()
for i, layer in enumerate(model.layers):
    print(i, layer.name, layer.trainable)
# Out:
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 74, 74, 32)   864         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 74, 74, 32)   96          conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 74, 74, 32)   0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# conv2d_189 (Conv2D)             (None, 72, 72, 32)   9216        activation_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_193 (BatchN (None, 72, 72, 32)   96          conv2d_189[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 72, 72, 32)   0           batch_normalization_193[0][0]
# __________________________________________________________________________________________________
# conv2d_190 (Conv2D)             (None, 72, 72, 64)   18432       activation_189[0][0]
# __________________________________________________________________________________________________
# batch_normalization_194 (BatchN (None, 72, 72, 64)   192         conv2d_190[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 72, 72, 64)   0           batch_normalization_194[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 35, 35, 64)   0           activation_190[0][0]
# __________________________________________________________________________________________________
# conv2d_191 (Conv2D)             (None, 35, 35, 80)   5120        max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 35, 35, 80)   240         conv2d_191[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 35, 35, 80)   0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# conv2d_192 (Conv2D)             (None, 33, 33, 192)  138240      activation_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 33, 33, 192)  576         conv2d_192[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 33, 33, 192)  0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 16, 16, 192)  0           activation_192[0][0]
# __________________________________________________________________________________________________
# conv2d_196 (Conv2D)             (None, 16, 16, 64)   12288       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 16, 16, 64)   192         conv2d_196[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 16, 16, 64)   0           batch_normalization_200[0][0]
# __________________________________________________________________________________________________
# conv2d_194 (Conv2D)             (None, 16, 16, 48)   9216        max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_197 (Conv2D)             (None, 16, 16, 96)   55296       activation_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 16, 16, 48)   144         conv2d_194[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 16, 16, 96)   288         conv2d_197[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 16, 16, 48)   0           batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 16, 16, 96)   0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# average_pooling2d
ch_normalization_278[0][0]
# __________________________________________________________________________________________________
# activation_278 (Activation)     (None, 3, 3, 384)    0           batch_normalization_282[0][0]
# __________________________________________________________________________________________________
# conv2d_275 (Conv2D)             (None, 3, 3, 384)    442368      activation_274[0][0]
# __________________________________________________________________________________________________
# conv2d_276 (Conv2D)             (None, 3, 3, 384)    442368      activation_274[0][0]
# __________________________________________________________________________________________________
# conv2d_279 (Conv2D)             (None, 3, 3, 384)    442368      activation_278[0][0]
# __________________________________________________________________________________________________
# conv2d_280 (Conv2D)             (None, 3, 3, 384)    442368      activation_278[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_26 (AveragePo (None, 3, 3, 2048)   0           mixed9[0][0]
# __________________________________________________________________________________________________
# conv2d_273 (Conv2D)             (None, 3, 3, 320)    655360      mixed9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_279 (BatchN (None, 3, 3, 384)    1152        conv2d_275[0][0]
# __________________________________________________________________________________________________
# batch_normalization_280 (BatchN (None, 3, 3, 384)    1152        conv2d_276[0][0]
# __________________________________________________________________________________________________
# batch_normalization_283 (BatchN (None, 3, 3, 384)    1152        conv2d_279[0][0]
# __________________________________________________________________________________________________
# batch_normalization_284 (BatchN (None, 3, 3, 384)    1152        conv2d_280[0][0]
# __________________________________________________________________________________________________
# conv2d_281 (Conv2D)             (None, 3, 3, 192)    393216      average_pooling2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_277 (BatchN (None, 3, 3, 320)    960         conv2d_273[0][0]
# __________________________________________________________________________________________________
# activation_275 (Activation)     (None, 3, 3, 384)    0           batch_normalization_279[0][0]
# __________________________________________________________________________________________________
# activation_276 (Activation)     (None, 3, 3, 384)    0           batch_normalization_280[0][0]
# __________________________________________________________________________________________________
# activation_279 (Activation)     (None, 3, 3, 384)    0           batch_normalization_283[0][0]
# __________________________________________________________________________________________________
# activation_280 (Activation)     (None, 3, 3, 384)    0           batch_normalization_284[0][0]
# __________________________________________________________________________________________________
# batch_normalization_285 (BatchN (None, 3, 3, 192)    576         conv2d_281[0][0]
# __________________________________________________________________________________________________
# activation_273 (Activation)     (None, 3, 3, 320)    0           batch_normalization_277[0][0]
# __________________________________________________________________________________________________
# mixed9_1 (Concatenate)          (None, 3, 3, 768)    0           activation_275[0][0]
#                                                                  activation_276[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 3, 3, 768)    0           activation_279[0][0]
#                                                                  activation_280[0][0]
# __________________________________________________________________________________________________
# activation_281 (Activation)     (None, 3, 3, 192)    0           batch_normalization_285[0][0]
# __________________________________________________________________________________________________
# mixed10 (Concatenate)           (None, 3, 3, 2048)   0           activation_273[0][0]
#                                                                  mixed9_1[0][0]
#                                                                  concatenate_5[0][0]
#                                                                  activation_281[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 2048)         0           mixed10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_286 (BatchN (None, 2048)         8192        global_average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1280)         2622720     batch_normalization_286[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1280)         0           dense_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_287 (BatchN (None, 1280)         5120        dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 4)            5124        batch_normalization_287[0][0]
# ==================================================================================================
# Total params: 24,443,940
# Trainable params: 2,634,500
# Non-trainable params: 21,809,440
# __________________________________________________________________________________________________
# 0 input_3 False
# 1 conv2d_188 False
# 2 batch_normalization_192 False
# 3 activation_188 False
# 4 conv2d_189 False
# 5 batch_normalization_193 False
# 6 activation_189 False
# 7 conv2d_190 False
# 8 batch_normalization_194 False
# 9 activation_190 False
# 10 max_pooling2d_8 False
# 11 conv2d_191 False
# 12 batch_normalization_195 False
# 13 activation_191 False
# 14 conv2d_192 False
# 15 batch_normalization_196 False
# 16 activation_192 False
# 17 max_pooling2d_9 False
# 18 conv2d_196 False
# 19 batch_normalization_200 False
# 20 activation_196 False
# 21 conv2d_194 False
# 22 conv2d_197 False
# 23 batch_normalization_198 False
# 24 batch_normalization_201 False
# 25 activation_194 False
# 26 activation_197 False
# 27 average_pooling2d_18 False
# 28 conv2d_193 False
# 29 conv2d_195 False
# 30 conv2d_198 False
# 31 conv2d_199 False
# 32 batch_normalization_197 False
# 33 batch_normalization_199 False
# 34 batch_normalization_202 False
# 35 batch_normalization_203 False
# 36 activation_193 False
# 37 activation_195 False
# 38 activation_198 False
# 39 activation_199 False
# 40 mixed0 False
# 41 conv2d_203 False
# 42 batch_normalization_207 False
# 43 activation_203 False
# 44 conv2d_201 False
# 45 conv2d_204 False
# 46 batch_normalization_205 False
# 47 batch_normalization_208 False
# 48 activation_201 False
# 49 activation_204 False
# 50 average_pooling2d_19 False
# 51 conv2d_200 False
# 52 conv2d_202 False
# 53 conv2d_205 False
# 54 conv2d_206 False
# 55 batch_normalization_204 False
# 56 batch_normalization_206 False
# 57 batch_normalization_209 False
# 58 batch_normalization_210 False
# 59 activation_200 False
# 60 activation_202 False
# 61 activation_205 False
# 62 activation_206 False
# 63 mixed1 False
# 64 conv2d_210 False
# 65 batch_normalization_214 False
# 66 activation_210 False
# 67 conv2d_208 False
# 68 conv2d_211 False
# 69 batch_normalization_212 False
# 70 batch_normalization_215 False
# 71 activation_208 False
# 72 activation_211 False
# 73 average_pooling2d_20 False
# 74 conv2d_207 False
# 75 conv2d_209 False
# 76 conv2d_212 False
# 77 conv2d_213 False
# 78 batch_normalization_211 False
# 79 batch_normalization_213 False
# 80 batch_normalization_216 False
# 81 batch_normalization_217 False
# 82 activation_207 False
# 83 activation_209 False
# 84 activation_212 False
# 85 activation_213 False
# 86 mixed2 False
# 87 conv2d_215 False
# 88 batch_normalization_219 False
# 89 activation_215 False
# 90 conv2d_216 False
# 91 batch_normalization_220 False
# 92 activation_216 False
# 93 conv2d_214 False
# 94 conv2d_217 False
# 95 batch_normalization_218 False
# 96 batch_normalization_221 False
# 97 activation_214 False
# 98 activation_217 False
# 99 max_pooling2d_10 False
# 100 mixed3 False
# 101 conv2d_222 False
# 102 batch_normalization_226 False
# 103 activation_222 False
# 104 conv2d_223 False
# 105 batch_normalization_227 False
# 106 activation_223 False
# 107 conv2d_219 False
# 108 conv2d_224 False
# 109 batch_normalization_223 False
# 110 batch_normalization_228 False
# 111 activation_219 False
# 112 activation_224 False
# 113 conv2d_220 False
# 114 conv2d_225 False
# 115 batch_normalization_224 False
# 116 batch_normalization_229 False
# 117 activation_220 False
# 118 activation_225 False
# 119 average_pooling2d_21 False
# 120 conv2d_218 False
# 121 conv2d_221 False
# 122 conv2d_226 False
# 123 conv2d_227 False
# 124 batch_normalization_222 False
# 125 batch_normalization_225 False
# 126 batch_normalization_230 False
# 127 batch_normalization_231 False
# 128 activation_218 False
# 129 activation_221 False
# 130 activation_226 False
# 131 activation_227 False
# 132 mixed4 False
# 133 conv2d_232 False
# 134 batch_normalization_236 False
# 135 activation_232 False
# 136 conv2d_233 False
# 137 batch_normalization_237 False
# 138 activation_233 False
# 139 conv2d_229 False
# 140 conv2d_234 False
# 141 batch_normalization_233 False
# 142 batch_normalization_238 False
# 143 activation_229 False
# 144 activation_234 False
# 145 conv2d_230 False
# 146 conv2d_235 False
# 147 batch_normalization_234 False
# 148 batch_normalization_239 False
# 149 activation_230 False
# 150 activation_235 False
# 151 average_pooling2d_22 False
# 152 conv2d_228 False
# 153 conv2d_231 False
# 154 conv2d_236 False
# 155 conv2d_237 False
# 156 batch_normalization_232 False
# 157 batch_normalization_235 False
# 158 batch_normalization_240 False
# 159 batch_normalization_241 False
# 160 activation_228 False
# 161 activation_231 False
# 162 activation_236 False
# 163 activation_237 False
# 164 mixed5 False
# 165 conv2d_242 False
# 166 batch_normalization_246 False
# 167 activation_242 False
# 168 conv2d_243 False
# 169 batch_normalization_247 False
# 170 activation_243 False
# 171 conv2d_239 False
# 172 conv2d_244 False
# 173 batch_normalization_243 False
# 174 batch_normalization_248 False
# 175 activation_239 False
# 176 activation_244 False
# 177 conv2d_240 False
# 178 conv2d_245 False
# 179 batch_normalization_244 False
# 180 batch_normalization_249 False
# 181 activation_240 False
# 182 activation_245 False
# 183 average_pooling2d_23 False
# 184 conv2d_238 False
# 185 conv2d_241 False
# 186 conv2d_246 False
# 187 conv2d_247 False
# 188 batch_normalization_242 False
# 189 batch_normalization_245 False
# 190 batch_normalization_250 False
# 191 batch_normalization_251 False
# 192 activation_238 False
# 193 activation_241 False
# 194 activation_246 False
# 195 activation_247 False
# 196 mixed6 False
# 197 conv2d_252 False
# 198 batch_normalization_256 False
# 199 activation_252 False
# 200 conv2d_253 False
# 201 batch_normalization_257 False
# 202 activation_253 False
# 203 conv2d_249 False
# 204 conv2d_254 False
# 205 batch_normalization_253 False
# 206 batch_normalization_258 False
# 207 activation_249 False
# 208 activation_254 False
# 209 conv2d_250 False
# 210 conv2d_255 False
# 211 batch_normalization_254 False
# 212 batch_normalization_259 False
# 213 activation_250 False
# 214 activation_255 False
# 215 average_pooling2d_24 False
# 216 conv2d_248 False
# 217 conv2d_251 False
# 218 conv2d_256 False
# 219 conv2d_257 False
# 220 batch_normalization_252 False
# 221 batch_normalization_255 False
# 222 batch_normalization_260 False
# 223 batch_normalization_261 False
# 224 activation_248 False
# 225 activation_251 False
# 226 activation_256 False
# 227 activation_257 False
# 228 mixed7 False
# 229 conv2d_260 False
# 230 batch_normalization_264 False
# 231 activation_260 False
# 232 conv2d_261 False
# 233 batch_normalization_265 False
# 234 activation_261 False
# 235 conv2d_258 False
# 236 conv2d_262 False
# 237 batch_normalization_262 False
# 238 batch_normalization_266 False
# 239 activation_258 False
# 240 activation_262 False
# 241 conv2d_259 False
# 242 conv2d_263 False
# 243 batch_normalization_263 False
# 244 batch_normalization_267 False
# 245 activation_259 False
# 246 activation_263 False
# 247 max_pooling2d_11 False
# 248 mixed8 False
# 249 conv2d_268 False
# 250 batch_normalization_272 False
# 251 activation_268 False
# 252 conv2d_265 False
# 253 conv2d_269 False
# 254 batch_normalization_269 False
# 255 batch_normalization_273 False
# 256 activation_265 False
# 257 activation_269 False
# 258 conv2d_266 False
# 259 conv2d_267 False
# 260 conv2d_270 False
# 261 conv2d_271 False
# 262 average_pooling2d_25 False
# 263 conv2d_264 False
# 264 batch_normalization_270 False
# 265 batch_normalization_271 False
# 266 batch_normalization_274 False
# 267 batch_normalization_275 False
# 268 conv2d_272 False
# 269 batch_normalization_268 False
# 270 activation_266 False
# 271 activation_267 False
# 272 activation_270 False
# 273 activation_271 False
# 274 batch_normalization_276 False
# 275 activation_264 False
# 276 mixed9_0 False
# 277 concatenate_4 False
# 278 activation_272 False
# 279 mixed9 False
# 280 conv2d_277 False
# 281 batch_normalization_281 False
# 282 activation_277 False
# 283 conv2d_274 False
# 284 conv2d_278 False
# 285 batch_normalization_278 False
# 286 batch_normalization_282 False
# 287 activation_274 False
# 288 activation_278 False
# 289 conv2d_275 False
# 290 conv2d_276 False
# 291 conv2d_279 False
# 292 conv2d_280 False
# 293 average_pooling2d_26 False
# 294 conv2d_273 False
# 295 batch_normalization_279 False
# 296 batch_normalization_280 False
# 297 batch_normalization_283 False
# 298 batch_normalization_284 False
# 299 conv2d_281 False
# 300 batch_normalization_277 False
# 301 activation_275 False
# 302 activation_276 False
# 303 activation_279 False
# 304 activation_280 False
# 305 batch_normalization_285 False
# 306 activation_273 False
# 307 mixed9_1 False
# 308 concatenate_5 False
# 309 activation_281 False
# 310 mixed10 False
# 311 global_average_pooling2d_2 True
# 312 batch_normalization_286 True
# 313 dense_4 True
# 314 dropout_2 True
# 315 batch_normalization_287 True
# 316 dense_5 True

# %%
# %%time
t=time.time()
history = model.fit_generator(generator=train_generator, 
                                steps_per_epoch=len(train_generator), 
                                validation_data=validation_generator, 
                                validation_steps=len(validation_generator),
                                epochs=epochs,
                                callbacks=[reducelr])

#compute the training time
print('Training time: %s' % (time.time()-t))
# Out:
# WARNING:tensorflow:From <timed exec>:7: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 39 steps, validate for 9 steps
# Epoch 1/100
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.8 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# 39/39 [==============================] - 172s 4s/step - loss: 1.4320 - accuracy: 0.3870 - val_loss: 1.8693 - val_accuracy: 0.2910
# Epoch 2/100
# 39/39 [==============================] - 137s 4s/step - loss: 1.2355 - accuracy: 0.4713 - val_loss: 1.4108 - val_accuracy: 0.3993
# Epoch 3/100
# 39/39 [==============================] - 138s 4s/step - loss: 1.0770 - accuracy: 0.5377 - val_loss: 1.2938 - val_accuracy: 0.4664
# Epoch 4/100
# 39/39 [==============================] - 135s 3s/step - loss: 0.9962 - accuracy: 0.5717 - val_loss: 1.0998 - val_accuracy: 0.5821
# Epoch 5/100
# 39/39 [==============================] - 140s 4s/step - loss: 0.9836 - accuracy: 0.5830 - val_loss: 1.0161 - val_accuracy: 0.5746
# Epoch 6/100
# 39/39 [==============================] - 141s 4s/step - loss: 0.8832 - accuracy: 0.6243 - val_loss: 0.9490 - val_accuracy: 0.6269
# Epoch 7/100
# 39/39 [==============================] - 138s 4s/step - loss: 0.8223 - accuracy: 0.6656 - val_loss: 0.9395 - val_accuracy: 0.6418
# Epoch 8/100
# 39/39 [==============================] - 136s 3s/step - loss: 0.8262 - accuracy: 0.6599 - val_loss: 0.8625 - val_accuracy: 0.6642
# Epoch 9/100
# 39/39 [==============================] - 139s 4s/step - loss: 0.7958 - accuracy: 0.6680 - val_loss: 0.8449 - val_accuracy: 0.6828
# Epoch 10/100
# 39/39 [==============================] - 146s 4s/step - loss: 0.7909 - accuracy: 0.6648 - val_loss: 0.8864 - val_accuracy: 0.6679
# Epoch 11/100
# 39/39 [==============================] - 141s 4s/step - loss: 0.7663 - accuracy: 0.6858 - val_loss: 0.7979 - val_accuracy: 0.7015
# Epoch 12/100
# 39/39 [==============================] - 137s 4s/step - loss: 0.7631 - accuracy: 0.6907 - val_loss: 0.8732 - val_accuracy: 0.6866
# Epoch 13/100
# 39/39 [==============================] - 144s 4s/step - loss: 0.7532 - accuracy: 0.6891 - val_loss: 0.8821 - val_accuracy: 0.6791
# Epoch 14/100
# 39/39 [==============================] - 139s 4s/step - loss: 0.7361 - accuracy: 0.6955 - val_loss: 0.8607 - val_accuracy: 0.7015
# Epoch 15/100
# 39/39 [==============================] - 139s 4s/step - loss: 0.6981 - accuracy: 0.7134 - val_loss: 0.8324 - val_accuracy: 0.6828
# Epoch 16/100
# 39/39 [==============================] - 147s 4s/step - loss: 0.6130 - accuracy: 0.7498 - val_loss: 0.8178 - val_accuracy: 0.7239
# Epoch 36/100
# 39/39 [==============================] - 144s 4s/step - loss: 0.5923 - accuracy: 0.7522 - val_loss: 0.8177 - val_accuracy: 0.7201
# Epoch 37/100
# 39/39 [==============================] - 147s 4s/step - loss: 0.6064 - accuracy: 0.7563 - val_loss: 0.7970 - val_accuracy: 0.7201
# Epoch 38/100
# 38/39 [============================>.] - ETA: 3s - loss: 0.5886 - accuracy: 0.7556
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 3.162277292675049e-06.
# 39/39 [==============================] - 136s 3s/step - loss: 0.5925 - accuracy: 0.7579 - val_loss: 0.8641 - val_accuracy: 0.7052
# Epoch 39/100
# 39/39 [==============================] - 135s 3s/step - loss: 0.6287 - accuracy: 0.7401 - val_loss: 0.8478 - val_accuracy: 0.7127
# Epoch 40/100
# 39/39 [==============================] - 135s 3s/step - loss: 0.6078 - accuracy: 0.7506 - val_loss: 0.8498 - val_accuracy: 0.7239
# Epoch 41/100
# 39/39 [==============================] - 134s 3s/step - loss: 0.6224 - accuracy: 0.7287 - val_loss: 0.7873 - val_accuracy: 0.7500
# Epoch 42/100
# 39/39 [==============================] - 137s 4s/step - loss: 0.5962 - accuracy: 0.7717 - val_loss: 0.8473 - val_accuracy: 0.7463
# Epoch 43/100
# 39/39 [==============================] - 132s 3s/step - loss: 0.6077 - accuracy: 0.7498 - val_loss: 0.7940 - val_accuracy: 0.7127
# Epoch 44/100
# 39/39 [==============================] - 136s 3s/step - loss: 0.6281 - accuracy: 0.7312 - val_loss: 0.7723 - val_accuracy: 0.7575
# Epoch 45/100
# 39/39 [==============================] - 132s 3s/step - loss: 0.6017 - accuracy: 0.7587 - val_loss: 0.8514 - val_accuracy: 0.7015
# Epoch 46/100
# 39/39 [==============================] - 132s 3s/step - loss: 0.5965 - accuracy: 0.7547 - val_loss: 0.8034 - val_accuracy: 0.7052
# Epoch 47/100
# 39/39 [==============================] - 133s 3s/step - loss: 0.5888 - accuracy: 0.7611 - val_loss: 0.9052 - val_accuracy: 0.7164
# Epoch 48/100
# 39/39 [==============================] - 133s 3s/step - loss: 0.6170 - accuracy: 0.7368 - val_loss: 0.7680 - val_accuracy: 0.7201
# Epoch 49/100
# 38/39 [============================>.] - ETA: 3s - loss: 0.6110 - accuracy: 0.7348
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 9.999999115286567e-07.
# 39/39 [==============================] - 132s 3s/step - loss: 0.6105 - accuracy: 0.7352 - val_loss: 0.7891 - val_accuracy: 0.7575
# Epoch 50/100
# 39/39 [==============================] - 132s 3s/step - loss: 0.6262 - accuracy: 0.7563 - val_loss: 0.8250 - val_accuracy: 0.7052
# Epoch 51/100
# 39/39 [==============================] - 132s 3s/step - loss: 0.6030 - accuracy: 0.7603 - val_loss: 0.8360 - val_accuracy: 0.7164
# Epoch 52/100
# 39/39 [==============================] - 131s 3s/step - loss: 0.6201 - accuracy: 0.7466 - val_loss: 0.8408 - val_accuracy: 0.6978
# Epoch 53/100
# 39/39 [==============================] - 133s 3s/step - loss: 0.6323 - accuracy: 0.7368 - val_loss: 0.8035 - val_accuracy: 0.7425
# Epoch 54/100
# 38/39 [============================>.] - ETA: 3s - loss: 0.5717 - accuracy: 0.7697
# Epoch 00054: ReduceLROnPlateau reducing learning rate to
100
# 39/39 [==============================] - 137s 4s/step - loss: 0.5915 - accuracy: 0.7579 - val_loss: 0.7749 - val_accuracy: 0.7649
# Epoch 77/100
# 39/39 [==============================] - 136s 3s/step - loss: 0.6111 - accuracy: 0.7449 - val_loss: 0.8160 - val_accuracy: 0.7388
# Epoch 78/100
# 39/39 [==============================] - 135s 3s/step - loss: 0.5933 - accuracy: 0.7611 - val_loss: 0.7852 - val_accuracy: 0.7127
# Epoch 79/100
# 39/39 [==============================] - 137s 4s/step - loss: 0.5999 - accuracy: 0.7555 - val_loss: 0.8630 - val_accuracy: 0.7201
# Epoch 80/100
# 39/39 [==============================] - 137s 4s/step - loss: 0.6109 - accuracy: 0.7498 - val_loss: 0.7558 - val_accuracy: 0.7015
# Epoch 81/100
# 38/39 [============================>.] - ETA: 3s - loss: 0.5968 - accuracy: 0.7531
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 1e-07.
# 39/39 [==============================] - 137s 4s/step - loss: 0.5942 - accuracy: 0.7547 - val_loss: 0.8194 - val_accuracy: 0.7351
# Epoch 82/100
# 39/39 [==============================] - 137s 4s/step - loss: 0.6094 - accuracy: 0.7506 - val_loss: 0.8034 - val_accuracy: 0.7127
# Epoch 83/100
# 39/39 [==============================] - 137s 4s/step - loss: 0.5841 - accuracy: 0.7530 - val_loss: 0.8766 - val_accuracy: 0.6940
# Epoch 84/100
# 39/39 [==============================] - 136s 3s/step - loss: 0.6037 - accuracy: 0.7506 - val_loss: 0.8001 - val_accuracy: 0.7388
# Epoch 85/100
# 39/39 [==============================] - 135s 3s/step - loss: 0.5742 - accuracy: 0.7773 - val_loss: 0.7340 - val_accuracy: 0.7463
# Epoch 86/100
# 38/39 [============================>.] - ETA: 3s - loss: 0.5965 - accuracy: 0.7523
# Epoch 00086: ReduceLROnPlateau reducing learning rate to 1e-07.
# 39/39 [==============================] - 137s 4s/step - loss: 0.5986 - accuracy: 0.7522 - val_loss: 0.7790 - val_accuracy: 0.7313
# Epoch 87/100
# 39/39 [==============================] - 137s 4s/step - loss: 0.5757 - accuracy: 0.7644 - val_loss: 0.7599 - val_accuracy: 0.7537
# Epoch 88/100
# 39/39 [==============================] - 137s 4s/step - loss: 0.6336 - accuracy: 0.7296 - val_loss: 0.8191 - val_accuracy: 0.7239
# Epoch 89/100
# 39/39 [==============================] - 137s 4s/step - loss: 0.5850 - accuracy: 0.7628 - val_loss: 0.7743 - val_accuracy: 0.7425
# Epoch 90/100
# 39/39 [==============================] - 136s 3s/step - loss: 0.6324 - accuracy: 0.7474 - val_loss: 0.8119 - val_accuracy: 0.7575
# Epoch 91/100
# 38/39 [============================>.] - ETA: 3s - loss: 0.5944 - accuracy: 0.7639
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 1e-07.
# 39/39 [==============================] - 135s 3s/step - loss: 0.5944 - accuracy: 0.7628 - val_loss: 0.8578 - val_accuracy: 0.7239
# Epoch 92/100
# 39/39 [==============================] - 135s 3s/step - loss: 0.5905 - accuracy: 0.7611 - val_loss: 0.7839 - val_accuracy: 0.7015
# Epoch 93/100
# 39/39 [==============================] - 138s 4s/step - loss: 0.5921 - accuracy: 0.7595 - val_loss: 0.8353 - val_accuracy: 0.7313
# Epoch 94/100
# 39/39 [==============================] - 137s 4s/step - loss: 0.5922 - accuracy: 0.7652 - val_loss: 0.7858 - val_accuracy: 0.7276
# Epoch 95/100
# 39/39 [==============================] - 137s 4s/step - loss: 0.6065 - accuracy: 0.7385 - val_loss: 0.8333 - val_accuracy: 0.7276
# Epoch 96/100
# 38/39 [============================>.] - ETA: 3s - loss: 0.6238 - accuracy: 0.7465
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 1e-07.
# 39/39 [==============================] - 137s 4s/step - loss: 0.6213 - accuracy: 0.7466 - val_loss: 0.7260 - val_accuracy: 0.7575
# Epoch 97/100
# 39/39 [==============================] - 136s 3s/step - loss: 0.5793 - accuracy: 0.7579 - val_loss: 0.7967 - val_accuracy: 0.7649
# Epoch 98/100
# 39/39 [==============================] - 135s 3s/step - loss: 0.6099 - accuracy: 0.7530 - val_loss: 0.8012 - val_accuracy: 0.7127
# Epoch 99/100
# 39/39 [==============================] - 137s 4s/step - loss: 0.5893 - accuracy: 0.7563 - val_loss: 0.9186 - val_accuracy: 0.6978
# Epoch 100/100
# 39/39 [==============================] - 138s 4s/step - loss: 0.5996 - accuracy: 0.7619 - val_loss: 0.8525 - val_accuracy: 0.7351
# Training time: 13778.1122777462
# Wall time: 3h 49min 38s

# %%
# %%time
t=time.time()
history = model.fit_generator(generator=train_generator, 
                                steps_per_epoch=len(train_generator), 
                                validation_data=validation_generator, 
                                validation_steps=len(validation_generator),
                                epochs=epochs,
                                callbacks=[reducelr])

#compute the training time
print('Training time: %s' % (time.time()-t))
# Out:
# WARNING:tensorflow:From <timed exec>:7: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 39 steps, validate for 9 steps
# Epoch 1/100
# WARNING:tensorflow:Large dropout rate: 0.85 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# 39/39 [==============================] - 378s 10s/step - loss: 1.6608 - accuracy: 0.2559 - val_loss: 1.4001 - val_accuracy: 0.3097
# Epoch 2/100
# 39/39 [==============================] - 364s 9s/step - loss: 1.5449 - accuracy: 0.3109 - val_loss: 1.2701 - val_accuracy: 0.4179
# Epoch 3/100
# 39/39 [==============================] - 368s 9s/step - loss: 1.4020 - accuracy: 0.3806 - val_loss: 1.1238 - val_accuracy: 0.4627
# Epoch 4/100
# 39/39 [==============================] - 362s 9s/step - loss: 1.3868 - accuracy: 0.3741 - val_loss: 1.0249 - val_accuracy: 0.4776
# Epoch 5/100
# 39/39 [==============================] - 362s 9s/step - loss: 1.2569 - accuracy: 0.4413 - val_loss: 0.9433 - val_accuracy: 0.5187
# Epoch 6/100
# 39/39 [==============================] - 374s 10s/step - loss: 1.1887 - accuracy: 0.4680 - val_loss: 0.9491 - val_accuracy: 0.5410
# Epoch 7/100
# 39/39 [==============================] - 365s 9s/step - loss: 1.1539 - accuracy: 0.4907 - val_loss: 0.9127 - val_accuracy: 0.5410
# Epoch 8/100
# 39/39 [==============================] - 360s 9s/step - loss: 1.0891 - accuracy: 0.4955 - val_loss: 0.8864 - val_accuracy: 0.5933
# Epoch 9/100
# 39/39 [==============================] - 366s 9s/step - loss: 1.0526 - accuracy: 0.5336 - val_loss: 0.8798 - val_accuracy: 0.5634
# Epoch 10/100
# 39/39 [==============================] - 366s 9s/step - loss: 1.0498 - accuracy: 0.5077 - val_loss: 0.8489 - val_accuracy: 0.5821
# Epoch 11/100
# 39/39 [==============================] - 364s 9s/step - loss: 1.0628 - accuracy: 0.5036 - val_loss: 0.8076 - val_accuracy: 0.6306
# Epoch 12/100
# 39/39 [==============================] - 360s 9s/step - loss: 0.9882 - accuracy: 0.5514 - val_loss: 0.7416 - val_accuracy: 0.6493
# Epoch 13/100
# 39/39 [==============================] - 361s 9s/step - loss: 0.9674 - accuracy: 0.5312 - val_loss: 0.7212 - val_accuracy: 0.6493
# Epoch 14/100
# Epoch 34/100
# 39/39 [==============================] - 359s 9s/step - loss: 0.5155 - accuracy: 0.7960 - val_loss: 0.4838 - val_accuracy: 0.8134
# Epoch 35/100
# 39/39 [==============================] - 366s 9s/step - loss: 0.5124 - accuracy: 0.8065 - val_loss: 0.4961 - val_accuracy: 0.7985
# Epoch 36/100
# 39/39 [==============================] - 364s 9s/step - loss: 0.4823 - accuracy: 0.8146 - val_loss: 0.5337 - val_accuracy: 0.8246
# Epoch 37/100
# 39/39 [==============================] - 359s 9s/step - loss: 0.5004 - accuracy: 0.8040 - val_loss: 0.4508 - val_accuracy: 0.8358
# Epoch 38/100
# 39/39 [==============================] - 360s 9s/step - loss: 0.4773 - accuracy: 0.8275 - val_loss: 0.4220 - val_accuracy: 0.8433
# Epoch 39/100
# 39/39 [==============================] - 368s 9s/step - loss: 0.4628 - accuracy: 0.8332 - val_loss: 0.3878 - val_accuracy: 0.8507
# Epoch 40/100
# 39/39 [==============================] - 365s 9s/step - loss: 0.4445 - accuracy: 0.8316 - val_loss: 0.4322 - val_accuracy: 0.8321
# Epoch 41/100
# 39/39 [==============================] - 361s 9s/step - loss: 0.4532 - accuracy: 0.8283 - val_loss: 0.3859 - val_accuracy: 0.8694
# Epoch 42/100
# 39/39 [==============================] - 375s 10s/step - loss: 0.4353 - accuracy: 0.8332 - val_loss: 0.3722 - val_accuracy: 0.8582
# Epoch 43/100
# 39/39 [==============================] - 357s 9s/step - loss: 0.4042 - accuracy: 0.8534 - val_loss: 0.3961 - val_accuracy: 0.8694
# Epoch 44/100
# 39/39 [==============================] - 365s 9s/step - loss: 0.3721 - accuracy: 0.8737 - val_loss: 0.4010 - val_accuracy: 0.8470
# Epoch 45/100
# 39/39 [==============================] - 372s 10s/step - loss: 0.3781 - accuracy: 0.8680 - val_loss: 0.3440 - val_accuracy: 0.8881
# Epoch 46/100
# 39/39 [==============================] - 379s 10s/step - loss: 0.3500 - accuracy: 0.8713 - val_loss: 0.3487 - val_accuracy: 0.8955
# Epoch 47/100
# 39/39 [==============================] - 371s 10s/step - loss: 0.3525 - accuracy: 0.8761 - val_loss: 0.4208 - val_accuracy: 0.8582
# Epoch 48/100
# 39/39 [==============================] - 360s 9s/step - loss: 0.3478 - accuracy: 0.8737 - val_loss: 0.4196 - val_accuracy: 0.8657
# Epoch 49/100
# 39/39 [==============================] - 359s 9s/step - loss: 0.3396 - accuracy: 0.8777 - val_loss: 0.3950 - val_accuracy: 0.8843
# Epoch 50/100
# 39/39 [==============================] - 359s 9s/step - loss: 0.3476 - accuracy: 0.8891 - val_loss: 0.3613 - val_accuracy: 0.8806
# Epoch 51/100
# 38/39 [============================>.] - ETA: 8s - loss: 0.3067 - accuracy: 0.8953
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 3.1622775802825264e-05.
# 39/39 [==============================] - 359s 9s/step - loss: 0.3090 - accuracy: 0.8947 - val_loss: 0.3347 - val_accuracy: 0.8545
# Epoch 52/100
# 39/39 [==============================] - 361s 9s/step - loss: 0.3031 - accuracy: 0.9028 - val_loss: 0.3185 - val_accuracy: 0.9030
# Epoch 53/100
# 39/39 [==============================] - 363s 9s/step - loss: 0.2989 - accuracy: 0.8996 - val_loss: 0.3640 - val_accuracy: 0.8843
# Epoch 54/100
# 39/39 [==============================] - 361s 9s/step - loss: 0.3154 - accuracy: 0.8907 - val_loss: 0.3109 - val_accuracy: 0.9030
# Epoch 55/100
# 39/39 [==============================] - 371s 10s/step - loss: 0.3020 - accuracy: 0.9036 - val_loss: 0.3257 - val_accuracy: 0.8955
# Epoch 56/100
# 39/39 [==============================] - 357s 9s/step - loss: 0.2896 - accuracy: 0.9045 - val_loss: 0.3509 - val_accuracy: 0.8955
# Epoch 57/100
# 38/39 [============================>.] - ETA: 8s - loss: 0.2798 - accuracy: 0.9027
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 9.999999259090306e-06.
# 39/39 [==============================] - 362s 9s/step - loss: 0.2856 - accuracy: 0.9020 - val_loss: 0.3186 - val_accuracy: 0.8955
# Epoch 58/100
# 39/39 [==============================] - 360s 9s/step - loss: 0.2839 - accuracy: 0.9012 - val_loss: 0.2813 - val_accuracy: 0.8993
# Epoch 59/100
# 39/39 [==============================] - 359s 9s/step - loss: 0.2887 - accuracy: 0.9061 - val_loss: 0.2856 - val_accuracy: 0.9030
# Epoch 60/100
# 39/39 [==============================] - 359s 9s/step - loss: 0.2676 - accuracy: 0.9150 - val_loss: 0.3406 - val_accuracy: 0.8918
# Epoch 61/100
# 39/39 [==============================] - 359s 9s/step - loss: 0.2902 - accuracy: 0.8972 - val_loss: 0.3150 - val_accuracy: 0.9030
# Epoch 62/100
# 39/39 [==============================] - 359s 9s/step - loss: 0.2767 - accuracy: 0.9028 - val_loss: 0.2883 - val_accuracy: 0.9179
# Epoch 63/100
# 39/39 [==============================] - 360s 9s/step - loss: 0.2756 - accuracy: 0.9101 - val_loss: 0.2872 - val_accuracy: 0.9030
# Epoch 64/100
# 39/39 [==============================] - 358s 9s/step - loss: 0.2623 - accuracy: 0.9182 - val_loss: 0.3232 - val_accuracy: 0.8806
# Epoch 65/100
# 39/39 [==============================] - 375s 10s/step - loss: 0.2670 - accuracy: 0.9077 - val_loss: 0.3408 - val_accuracy: 0.8955
# Epoch 66/100
# 39/39 [==============================] - 365s 9s/step - loss: 0.2734 - accuracy: 0.9028 - val_loss: 0.3485 - val_accuracy: 0.8993
# Epoch 67/100
# 38/39 [============================>.] - ETA: 9s - loss: 0.2842 - accuracy: 0.9052
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 3.162277292675049e-06.
# 39/39 [==============================] - 369s 9s/step - loss: 0.2815 - accuracy: 0.9061 - val_loss: 0.3013 - val_accuracy: 0.8993
# Epoch 68/100
# 39/39 [==============================] - 370s 9s/step - loss: 0.2450 - accuracy: 0.9166 - val_loss: 0.2847 - val_accuracy: 0.8843
# Epoch 69/100
# 39/39 [==============================] - 381s 10s/step - loss: 0.2740 - accuracy: 0.9077 - val_loss: 0.3071 - val_accuracy: 0.8843
# Epoch 70/100
# 39/39 [==============================] - 372s 10s/step - loss: 0.2744 - accuracy: 0.9085 - val_loss: 0.3383 - val_accuracy: 0.9030
# Epoch 71/100
# 39/39 [==============================] - 365s 9s/step - loss: 0.2635 - accuracy: 0.9093 - val_loss: 0.2995 - val_accuracy: 0.9030
# Epoch 72/100
# 39/39 [==============================] - 358s 9s/step - loss: 0.2711 - accuracy: 0.9020 - val_loss: 0.3001 - val_accuracy: 0.9254
# Epoch 73/100
# 39/39 [==============================] - 352s 9s/step - loss: 0.2562 - accuracy: 0.9231 - val_loss: 0.2852 - val_accuracy: 0.9030
# Epoch 74/100
# 39/39 [==============================] - 362s 9s/step - loss: 0.2805 - accuracy: 0.9036 - val_loss: 0.2946 - val_accuracy: 0.9067
# Epoch 75/100
# 39/39 [==============================] - 358s 9s/step - loss: 0.2966 - accuracy: 0.9004 - val_loss: 0.2990 - val_accuracy: 0.9142
# Epoch 76/100
# 39/39 [==============================] - 367s 9s/step - loss: 0.2521 - accuracy: 0.9142 - val_loss: 0.3316 - val_accuracy: 0.8843
# Epoch 77/100
# 38/39 [============================>.] - ETA: 8s - loss: 0.2576 - accuracy: 0.9194
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 9.999999115286567e-07.
# 39/39 [==============================] - 354s 9s/step - loss: 0.2591 - accuracy: 0.9174 - val_loss: 0.2864 - val_accuracy: 0.9142
# Epoch 78/100
# 39/39 [==============================] - 364s 9s/step - loss: 0.2545 - accuracy: 0.9223 - val_loss: 0.2823 - val_accuracy: 0.9067
# Epoch 79/100
# 39/39 [==============================] - 364s 9s/step - loss: 0.2509 - accuracy: 0.9142 - val_loss: 0.2842 - val_accuracy: 0.9142
# Epoch 80/100
# 39/39 [==============================] - 363s 9s/step - loss: 0.2714 - accuracy: 0.9020 - val_loss: 0.2487 - val_accuracy: 0.9142
# Epoch 81/100
# 39/39 [==============================] - 359s 9s/step - loss: 0.2517 - accuracy: 0.9182 - val_loss: 0.3697 - val_accuracy: 0.8694
# Epoch 82/100
# 38/39 [============================>.] - ETA: 9s - loss: 0.2583 - accuracy: 0.9185
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 3.1622772926750485e-07.
# 39/39 [==============================] - 366s 9s/step - loss: 0.2566 - accuracy: 0.9190 - val_loss: 0.2335 - val_accuracy: 0.9179
# Epoch 83/100
# 39/39 [==============================] - 361s 9s/step - loss: 0.2463 - accuracy: 0.9150 - val_loss: 0.2820 - val_accuracy: 0.9067
# Epoch 84/100
# 39/39 [==============================] - 362s 9s/step - loss: 0.2638 - accuracy: 0.9085 - val_loss: 0.2611 - val_accuracy: 0.8993
# Epoch 85/100
# 39/39 [==============================] - 351s 9s/step - loss: 0.2501 - accuracy: 0.9158 - val_loss: 0.2766 - val_accuracy: 0.9104
# Epoch 86/100
# 39/39 [==============================] - 350s 9s/step - loss: 0.2655 - accuracy: 0.9158 - val_loss: 0.2990 - val_accuracy: 0.9030
# Epoch 87/100
# 38/39 [============================>.] - ETA: 8s - loss: 0.2655 - accuracy: 0.9160
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 1e-07.
# 39/39 [==============================] - 351s 9s/step - loss: 0.2635 - accuracy: 0.9166 - val_loss: 0.3146 - val_accuracy: 0.8918
# Epoch 88/100
# 39/39 [==============================] - 349s 9s/step - loss: 0.2648 - accuracy: 0.9085 - val_loss: 0.3138 - val_accuracy: 0.9104
# Epoch 89/100
# 39/39 [==============================] - 352s 9s/step - loss: 0.2596 - accuracy: 0.9150 - val_loss: 0.2953 - val_accuracy: 0.9030
# Epoch 90/100
# 39/39 [==============================] - 350s 9s/step - loss: 0.2495 - accuracy: 0.9126 - val_loss: 0.2877 - val_accuracy: 0.9030
# Epoch 91/100
# 39/39 [==============================] - 349s 9s/step - loss: 0.2536 - accuracy: 0.9223 - val_loss: 0.2976 - val_accuracy: 0.8843
# Epoch 92/100
# 38/39 [============================>.] - ETA: 8s - loss: 0.2602 - accuracy: 0.9194
# Epoch 00092: ReduceLROnPlateau reducing learning rate to 1e-07.
# 39/39 [==============================] - 351s 9s/step - loss: 0.2589 - accuracy: 0.9198 - val_loss: 0.3175 - val_accuracy: 0.9067
# Epoch 93/100
# 39/39 [==============================] - 350s 9s/step - loss: 0.2547 - accuracy: 0.9255 - val_loss: 0.3067 - val_accuracy: 0.9067
# Epoch 94/100
# 39/39 [==============================] - 352s 9s/step - loss: 0.2708 - accuracy: 0.9077 - val_loss: 0.3643 - val_accuracy: 0.8769
# Epoch 95/100
# 39/39 [==============================] - 352s 9s/step - loss: 0.2594 - accuracy: 0.9223 - val_loss: 0.3218 - val_accuracy: 0.8993
# Epoch 96/100
# 39/39 [==============================] - 350s 9s/step - loss: 0.2642 - accuracy: 0.9117 - val_loss: 0.2871 - val_accuracy: 0.9067
# Epoch 97/100
# 38/39 [============================>.] - ETA: 8s - loss: 0.2735 - accuracy: 0.9077
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 1e-07.
# 39/39 [==============================] - 351s 9s/step - loss: 0.2716 - accuracy: 0.9085 - val_loss: 0.3254 - val_accuracy: 0.8881
# Epoch 98/100
# 39/39 [==============================] - 350s 9s/step - loss: 0.2507 - accuracy: 0.9206 - val_loss: 0.3579 - val_accuracy: 0.9030
# Epoch 99/100
# 39/39 [==============================] - 350s 9s/step - loss: 0.2697 - accuracy: 0.9109 - val_loss: 0.2811 - val_accuracy: 0.9067
# Epoch 100/100
# 39/39 [==============================] - 351s 9s/step - loss: 0.2425 - accuracy: 0.9231 - val_loss: 0.3306 - val_accuracy: 0.8843
# Training time: 36149.10194349289
# Wall time: 10h 2min 29s

# %%
import matplotlib.pyplot as plt

train_accuracy = 92.31
valid_accuracy =88.43
test_accuracy = 90.15
plt.style.use('fivethirtyeight')
    
accuracys = [train_accuracy, valid_accuracy, test_accuracy]
tick_labels = ["training set", "validation set", "testing set"]
plt.bar(range(3), accuracys)
plt.xlabel('data set')
plt.ylabel('accuracy in %')
plt.xticks(range(3), tick_labels)
for x_,y_ in zip(range(3), accuracys):
    plt.text(x_ - 0.1, y_, '%.3f'%y_)
plt.show()

# %%
model.save("googlenet.h5")

# %%
from tensorflow.keras.models import load_model

model = load_model('googlenet.h5')
# Out:
# WARNING:tensorflow:Large dropout rate: 0.85 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.85 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 150, 150, 3) 0
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 74, 74, 32)   864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 74, 74, 32)   96          conv2d_94[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 74, 74, 32)   0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 72, 72, 32)   9216        activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 72, 72, 32)   96          conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 72, 72, 32)   0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 72, 72, 64)   18432       activation_95[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 72, 72, 64)   192         conv2d_96[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 72, 72, 64)   0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 35, 35, 64)   0           activation_96[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 35, 35, 80)   5120        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 35, 35, 80)   240         conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None,
ropout_3[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 4)            5124        batch_normalization_191[0][0]
# ==================================================================================================
# Total params: 24,443,940
# Trainable params: 24,402,852
# Non-trainable params: 41,088
# __________________________________________________________________________________________________

# %%
import matplotlib.pyplot as plt
# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.style.use('fivethirtyeight')

plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.xlabel('Num of Epochs')
plt.ylabel('Accuracy')
plt.title(' Googlenet Training vs validation accuracy ')
plt.legend()
plt.figure()
plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('GoogleNet Training vs validation loss ')
plt.xlabel('Num of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
# Config the matplotlib backend as plotting inline in IPython
# %matplotlib inline

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.style.use('fivethirtyeight')

plt.plot(epochs, acc, label='Training acc')
plt.plot(epochs, val_acc, label='Validation acc')
plt.xlabel('Num of Epochs')
plt.ylabel('Accuracy')
plt.title(' Googlenet Training vs validation accuracy ')
plt.legend()
plt.figure()
plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('GoogleNet Training vs validation loss ')
plt.xlabel('Num of Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import numpy as np
accuracy = np.array(acc)
print(' Training Accuracy of model is      :   '  , accuracy[-1]*100,'%' )

val_accuracy = np.array(val_acc)
print('  Validation  Accuracy of model is      :   '  , val_accuracy[-1]*100,'%' )

t_loss = np.array(loss)
print('training   loss of   model   is     :   ' , t_loss[-1]*100,'%')
val_loss = np.array(val_loss)
print('Validation  loss of   model  is     :   ' , val_loss[-1]*100,'%')
# Out:
#  Training Accuracy of model is      :    76.19433403015137 %
#   Validation  Accuracy of model is      :    73.50746393203735 %
# training   loss of   model   is     :    59.75952313013888 %
# Validation  loss of   model  is     :    85.24604852621755 %

# %%
import numpy as np
accuracy = np.array(acc)
print(' Training Accuracy of model is      :   '  , accuracy[-1]*100,'%' )

val_accuracy = np.array(val_acc)
print('  Validation  Accuracy of model is      :   '  , val_accuracy[-1]*100,'%' )

t_loss = np.array(loss)
print('training   loss of   model   is     :   ' , t_loss[-1]*100,'%')
val_loss = np.array(val_loss)
print('Validation  loss of   model  is     :   ' , val_loss[-1]*100,'%')
# Out:
#  Training Accuracy of model is      :    92.30769276618958 %
#   Validation  Accuracy of model is      :    88.43283653259277 %
# training   loss of   model   is     :    24.379640302436073 %
# Validation  loss of   model  is     :    33.06103404611349 %

# %%
data_dir1 = "C:\\Users\\dagne\\Desktop\\common_bean_datasetv\\test"

datagen = ImageDataGenerator(
        shear_range=0.1,
        zoom_range=0.1,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        preprocessing_function=preprocess_input
)

test_generator = datagen.flow_from_directory(
        data_dir1,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical',
        shuffle=False,
     
        #subset="test"
)
# Out:
# Found 264 images belonging to 4 classes.

# %%
data_dir1 = "C:\\Users\\dagne\\Desktop\\common_bean_datasetv\\test"

datagen = ImageDataGenerator(
        shear_range=0.1,
        zoom_range=0.1,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        preprocessing_function=preprocess_input
)

test_generator = train_datagen.flow_from_directory(
        data_dir1,
        target_size=(150, 150),
        batch_size=32,
        class_mode='categorical',
        shuffle=False,
     
        #subset="test"
)
# Out:
# Found 264 images belonging to 4 classes.

# %%
score = model.evaluate_generator(test_generator, verbose=1)
# Out:
# WARNING:tensorflow:From <ipython-input-16-fb49b33d0ca4>:1: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 9/9 [==============================] - 31s 3s/step - loss: 0.9175 - accuracy: 0.7121

# %%
score = model.evaluate_generator(test_generator, verbose=1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 9/9 [==============================] - 40s 4s/step - loss: 0.2545 - accuracy: 0.9015

# %%
val_suffle=False

# %%
from sklearn.metrics import roc_auc_score,roc_curve,auc
import seaborn as sns
import pandas as pd
import numpy as np
import seaborn as sn
def plot_multiclass_roc(y_pred, y_test, n_classes,class_label, figsize=(17, 6)):
    
    # structures
    fpr = dict()
    tpr = dict()
    roc_auc = dict()

    # calculate dummies once
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test.iloc[:, i], y_pred[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # roc for each class
    fig, ax = plt.subplots(figsize=figsize)
    ax.plot([0, 1], [0, 1], 'k--')
    ax.set_xlim([0.0, 1.0])
    ax.set_ylim([0.0, 1.05])
    ax.set_xlabel('False Positive Rate')
    ax.set_ylabel('True Positive Rate')
    ax.set_title('Receiver operating characteristic example')
    for i,j in enumerate(class_label):
        print(i,j)
        ax.plot(fpr[i], tpr[i], label='ROC curve (area = {}) for label {}'.format(np.round(roc_auc[i],2),j))
    ax.legend(loc="best")
    ax.grid(alpha=.4)
    sns.despine()
    plt.show()

# %%
#Alexnet_model.evaluate(valid_set,steps=valid_set.n//batch_size)
#valid_set.reset()

model.evaluate(test_generator,steps=test_generator.n//batch_size)
test_generator.reset()

y_pred=model.predict(test_generator,steps=test_generator.n/batch_size,verbose=1)
class_label=list(test_generator.class_indices.keys())


if val_suffle==True:
  per = np.random.permutation(test_generator.n)
  test_generator.index_array = per
  y_true = test_generator.classes[per]
else: 
  y_true = test_generator.classes


plot_multiclass_roc( y_pred, pd.get_dummies(y_true), n_classes=4,class_label=class_label, figsize=(10, 5))
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 8/8 [==============================] - 38s 5s/step - loss: 0.3049 - accuracy: 0.8672
# 9/8 [================================] - 26s 3s/step
# 0 common_bean_Beetle
# 1 common_bean_brown_spot
# 2 common_bean_healthy
# 3 common_bean_rust

# %%
print(score)
# Out:
# [0.2987025012779567, 0.9015151]

# %%
test_generator.reset()
predictions = model.predict_generator(test_generator, steps=len(test_generator))
y = np.argmax(predictions, axis=1)

print('GoogleNet Classification Report')
cr = classification_report(y_true=test_generator.classes, y_pred=y, target_names=test_generator.class_indices)
print(cr)
# Out:
# WARNING:tensorflow:From <ipython-input-15-4b934b4f6e90>:2: Model.predict_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.predict, which supports generators.
# GoogleNet Classification Report
#                         precision    recall  f1-score   support
#
#     common_bean_Beetle       1.00      0.97      0.98        66
# common_bean_brown_spot       0.93      0.83      0.88        66
#    common_bean_healthy       0.85      1.00      0.92        66
#       common_bean_rust       0.84      0.80      0.82        66
#
#               accuracy                           0.90       264
#              macro avg       0.90      0.90      0.90       264
#           weighted avg       0.90      0.90      0.90       264

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
classes=['common_bean_Beetle', 'common_bean_brown_spot', 'common_bean_healthy','common_bean_rust']

preds=model.predict(test_generator)
y_pred=[]
y_true=[]
for i, p in enumerate(preds):
    y_pred.append(np.argmax(p))
    y_true.append(test_generator.labels[i])
y_pred=np.array(y_pred)
y_true=np.array(y_true)
cm = confusion_matrix(y_true, y_pred )
clr = classification_report(y_true, y_pred, target_names=classes)
length=len(classes)
plt.figure(figsize=(8, 8))
sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
plt.xticks(np.arange(length)+.5, classes, rotation= 90)
plt.yticks(np.arange(length)+.5, classes, rotation=0)
plt.xlabel("Predicted")
plt.ylabel("Actual ")
plt.title("GoogleNet Confusion Matrix")
plt.show()
