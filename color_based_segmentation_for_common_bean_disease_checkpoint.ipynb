# %%
import cv2
import numpy as np

low_green = np.array([36, 0, 0])
high_green = np.array([100, 255, 255])

while True:
    img1 = cv2.imread('C:\\Users\\dagne\\Desktop\\c.jpg')
    img1 = cv2.resize(img1, (256, 256), interpolation=cv2.INTER_CUBIC)
    
    # convert BGR to HSV
    imgHSV1 = cv2.cvtColor(img1, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV1, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res1 = cv2.bitwise_or(img1, img1, mask=mask)
    cv2.imshow("mask brown spot disease image", imgHSV1)
    cv2.imshow("orginal  Brown spot  disease image", img1)
    cv2.imshow('Segmented beetle disease image ', res1)
    
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\34.jpg",imgHSV1)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\35.jpg",mask)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\36.jpg",img1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    break

# %%
import cv2
import numpy as np

low_green = np.array([36, 0, 0])
high_green = np.array([100, 255, 255])

while True:
    img1 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (1).jpg')
    img1 = cv2.resize(img1, (256, 256), interpolation=cv2.INTER_CUBIC)
    img2 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (2).jpg')
    img2 = cv2.resize(img2, (256, 256), interpolation=cv2.INTER_CUBIC)
    img3 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (3).jpg')
    img3 = cv2.resize(img3, (256, 256), interpolation=cv2.INTER_CUBIC)
    img4 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (4).jpg')
    img4 = cv2.resize(img4, (256, 256), interpolation=cv2.INTER_CUBIC)
    img5 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (5).jpg')
    
    # convert BGR to HSV
    imgHSV1 = cv2.cvtColor(img1, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV1, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res1 = cv2.bitwise_or(img1, img1, mask=mask)
    cv2.imshow("mask brown spot disease image", mask)
    cv2.imshow("orginal  Brown spot  disease image", img1)
    cv2.imshow('Segmented beetle disease image ', res1)
    
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\34.jpg",res1)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\35.jpg",mask)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\36.jpg",img1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    break

# %%
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\1.jpg",res1)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\2.jpg",res2)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\3.jpg",res3)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\4.jpg",res4)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\5.jpg",res5)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\6.jpg",res6)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\7.jpg",res7)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\8.jpg",res8)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\9.jpg",res9)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\10.jpg",res10)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\11.jpg",res11)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\12.jpg",res12)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\13.jpg",res13)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\14.jpg",res14)

# %%
import cv2
import numpy as np
low_green = np.array([36, 0, 0])
high_green = np.array([100, 255, 255])
while True:
    img1 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (1).jpg')
    img1 = cv2.resize(img1, (256, 256), interpolation=cv2.INTER_CUBIC)
    img2 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (2).jpg')
    img2 = cv2.resize(img2, (256, 256), interpolation=cv2.INTER_CUBIC)
    img3 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (3).jpg')
    img3 = cv2.resize(img3, (256, 256), interpolation=cv2.INTER_CUBIC)
    img4 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (4).jpg')
    img4 = cv2.resize(img4, (256, 256), interpolation=cv2.INTER_CUBIC)
    img5 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (5).jpg')
    img5 = cv2.resize(img5, (256, 256), interpolation=cv2.INTER_CUBIC)
    img6 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (6).jpg')
    img6 = cv2.resize(img6, (256, 256), interpolation=cv2.INTER_CUBIC)
    img7 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (7).jpg')
    img7 = cv2.resize(img7, (256, 256), interpolation=cv2.INTER_CUBIC)
    img8 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (8).jpg')
    img8 = cv2.resize(img8, (256, 256), interpolation=cv2.INTER_CUBIC)
    img9 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (9).jpg')
    img9 = cv2.resize(img9, (256, 256), interpolation=cv2.INTER_CUBIC)
    img10 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (10).jpg')
    img10 = cv2.resize(img10, (256, 256), interpolation=cv2.INTER_CUBIC)
    img11 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (11).jpg')
    img11 = cv2.resize(img11, (256, 256), interpolation=cv2.INTER_CUBIC)
    img12 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (12).jpg')
    img12 = cv2.resize(img12, (256, 256), interpolation=cv2.INTER_CUBIC)
    img13 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (13).jpg')
    img13 = cv2.resize(img13, (256, 256), interpolation=cv2.INTER_CUBIC)
    img14 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (14).jpg')
    img14 = cv2.resize(img14, (256, 256), interpolation=cv2.INTER_CUBIC)
    img15 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (15).jpg')
    img15 = cv2.resize(img15, (256, 256), interpolation=cv2.INTER_CUBIC)
    img16 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (16).jpg')
    img16 = cv2.resize(img16, (256, 256), interpolation=cv2.INTER_CUBIC)
    img17 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (17).jpg')
    img17 = cv2.resize(img17, (256, 256), interpolation=cv2.INTER_CUBIC)
    img18 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (18).jpg')
    img18 = cv2.resize(img18, (256, 256), interpolation=cv2.INTER_CUBIC)
    img19 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (19).jpg')
    img19 = cv2.resize(img19, (256, 256), interpolation=cv2.INTER_CUBIC)
    img20 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (20).jpg')
    img20 = cv2.resize(img20, (256, 256), interpolation=cv2.INTER_CUBIC)
    img21 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (21).jpg')
    img21 = cv2.resize(img21, (256, 256), interpolation=cv2.INTER_CUBIC)
    img22 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (22).jpg')
    img22 = cv2.resize(img22, (256, 256), interpolation=cv2.INTER_CUBIC)
    img23 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (23).jpg')
    img23 = cv2.resize(img23, (256, 256), interpolation=cv2.INTER_CUBIC)
    img24 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (24).jpg')
    img24 = cv2.resize(img24, (256, 256), interpolation=cv2.INTER_CUBIC)
    img25 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (25).jpg')
    img25 = cv2.resize(img25, (256, 256), interpolation=cv2.INTER_CUBIC)
    img26 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (26).jpg')
    img26 = cv2.resize(img26, (256, 256), interpolation=cv2.INTER_CUBIC)
    img27 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (27).jpg')
    img27 = cv2.resize(img27, (256, 256), interpolation=cv2.INTER_CUBIC)
    img28 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (28).jpg')
    img28 = cv2.resize(img28, (256, 256), interpolation=cv2.INTER_CUBIC)
    img29 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (29).jpg')
    img29 = cv2.resize(img29, (256, 256), interpolation=cv2.INTER_CUBIC)
    img30 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (30).jpg')
    img30 = cv2.resize(img30, (256, 256), interpolation=cv2.INTER_CUBIC)
    img31 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (31).jpg')
    img31 = cv2.resize(img31, (256, 256), interpolation=cv2.INTER_CUBIC)
    img32 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (32).jpg')
    img32 = cv2.resize(img32, (256, 256), interpolation=cv2.INTER_CUBIC)
    img33 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (33).jpg')
    img33 = cv2.resize(img33, (256, 256), interpolation=cv2.INTER_CUBIC)
    img34 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (34).jpg')
    img34 = cv2.resize(img34, (256, 256), interpolation=cv2.INTER_CUBIC)
    img35 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (35).jpg')
    img35 = cv2.resize(img35, (256, 256), interpolation=cv2.INTER_CUBIC)
    img36 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (36).jpg')
    img36 = cv2.resize(img36, (256, 256), interpolation=cv2.INTER_CUBIC)
    
    # convert BGR to HSV
    imgHSV1 = cv2.cvtColor(img1, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV1, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res1 = cv2.bitwise_and(img1, img1, mask=mask)
    # convert BGR to HSV
    imgHSV2 = cv2.cvtColor(img2, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV2, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res2 = cv2.bitwise_and(img2, img2, mask=mask)
    # convert BGR to HSV
    imgHSV3 = cv2.cvtColor(img3, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV3, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res3 = cv2.bitwise_and(img3, img3, mask=mask)
    # convert BGR to HSV
    imgHSV4 = cv2.cvtColor(img4, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV4, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res4 = cv2.bitwise_and(img4, img4, mask=mask)
    # convert BGR to HSV
    imgHSV5 = cv2.cvtColor(img5, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV5, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res5 = cv2.bitwise_and(img5, img5, mask=mask)
    # convert BGR to HSV
    imgHSV6 = cv2.cvtColor(img6, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV6, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res6 = cv2.bitwise_and(img6, img6, mask=mask)
    # convert BGR to HSV
    imgHSV7 = cv2.cvtColor(img7, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV7, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res7 = cv2.bitwise_and(img7, img7, mask=mask)
    # convert BGR to HSV
    imgHSV8 = cv2.cvtColor(img8, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV8, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res8 = cv2.bitwise_and(img8, img8, mask=mask)
    # convert BGR to HSV
    imgHSV9 = cv2.cvtColor(img9, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV9, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res9 = cv2.bitwise_and(img9, img9, mask=mask)
    # convert BGR to HSV
    imgHSV10 = cv2.cvtColor(img10, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV10, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res10 = cv2.bitwise_and(img10, img10, mask=mask)
    # convert BGR to HSV
    imgHSV11 = cv2.cvtColor(img11, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV11, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res11 = cv2.bitwise_and(img11, img11, mask=mask)
    # convert BGR to HSV
    imgHSV12 = cv2.cvtColor(img12, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV12, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res12 = cv2.bitwise_and(img12, img12, mask=mask)
    # convert BGR to HSV
    imgHSV13 = cv2.cvtColor(img13, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV13, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res13 = cv2.bitwise_and(img13, img13, mask=mask)
    # convert BGR to HSV
    imgHSV14 = cv2.cvtColor(img14, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV14, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res14 = cv2.bitwise_and(img14, img14, mask=mask)
    # convert BGR to HSV
    imgHSV15 = cv2.cvtColor(img15, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV15, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res15 = cv2.bitwise_and(img15, img15, mask=mask)
    # convert BGR to HSV
    imgHSV16 = cv2.cvtColor(img16, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV16, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res16 = cv2.bitwise_and(img16, img16, mask=mask)
    # convert BGR to HSV
    imgHSV17 = cv2.cvtColor(img17, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV17, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res17 = cv2.bitwise_and(img17, img17, mask=mask)
    # convert BGR to HSV
    imgHSV18 = cv2.cvtColor(img18, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV18, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res18 = cv2.bitwise_and(img18, img18, mask=mask)
    # convert BGR to HSV
    imgHSV19 = cv2.cvtColor(img19, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV19, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res19 = cv2.bitwise_and(img19, img19, mask=mask)
    # convert BGR to HSV
    imgHSV20 = cv2.cvtColor(img20, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV20, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res20 = cv2.bitwise_and(img20, img20, mask=mask)
    # convert BGR to HSV
    imgHSV21 = cv2.cvtColor(img21, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV21, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res21 = cv2.bitwise_and(img21, img21, mask=mask)
    # convert BGR to HSV
    imgHSV22 = cv2.cvtColor(img22, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV22, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res22 = cv2.bitwise_and(img22, img22, mask=mask)
    # convert BGR to HSV
    imgHSV23 = cv2.cvtColor(img23, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV23, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res23 = cv2.bitwise_and(img23, img23, mask=mask)
    # convert BGR to HSV
    imgHSV24 = cv2.cvtColor(img24, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV24, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res24 = cv2.bitwise_and(img24, img24, mask=mask)
    # convert BGR to HSV
    imgHSV25 = cv2.cvtColor(img25, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV25, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res25 = cv2.bitwise_and(img25, img25, mask=mask)
    # convert BGR to HSV
    imgHSV26 = cv2.cvtColor(img26, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV26, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res26 = cv2.bitwise_and(img26, img26, mask=mask)
    # convert BGR to HSV
    imgHSV27 = cv2.cvtColor(img27, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV27, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res27 = cv2.bitwise_and(img27, img27, mask=mask)
    # convert BGR to HSV
    imgHSV28 = cv2.cvtColor(img28, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV28, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res28 = cv2.bitwise_and(img28, img28, mask=mask)
    # convert BGR to HSV
    imgHSV29 = cv2.cvtColor(img29, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV29, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res29 = cv2.bitwise_and(img29, img29, mask=mask)
    # convert BGR to HSV
    imgHSV30 = cv2.cvtColor(img30, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV30, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res30 = cv2.bitwise_and(img30, img30, mask=mask)
    # convert BGR to HSV
    imgHSV31 = cv2.cvtColor(img31, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV31, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res31 = cv2.bitwise_and(img31, img31, mask=mask)
    # convert BGR to HSV
    imgHSV32 = cv2.cvtColor(img32, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV32, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res32 = cv2.bitwise_and(img32, img32, mask=mask)
    # convert BGR to HSV
    imgHSV33 = cv2.cvtColor(img33, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV33, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res33 = cv2.bitwise_and(img33, img33, mask=mask)
    # convert BGR to HSV
    imgHSV34 = cv2.cvtColor(img34, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV34, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res34 = cv2.bitwise_and(img34, img34, mask=mask)
    # convert BGR to HSV
    imgHSV35 = cv2.cvtColor(img35, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV35, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res35 = cv2.bitwise_and(img35, img35, mask=mask)
    # convert BGR to HSV
    imgHSV36 = cv2.cvtColor(img36, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV36, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res36 = cv2.bitwise_and(img36, img36, mask=mask)

    #cv2.imshow("mask", mask)
    #cv2.imshow("cam", img1)
    0
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\37.jpg",res4)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\38.jpg",res5)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\39.jpg",res6)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\40.jpg",res7)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\41.jpg",res8)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\42.jpg",res9)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\43.jpg",res10)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\44.jpg",res11)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\45.jpg",res12)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\46.jpg",res13)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\47.jpg",res14)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\48.jpg",res15)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\49.jpg",res16)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\50.jpg",res17)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\51.jpg",res18)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\52.jpg",res19)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\53.jpg",res20)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\54.jpg",res21)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\55.jpg",res22)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\56.jpg",res23)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\57.jpg",res24)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\58.jpg",res25)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\59.jpg",res26)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\60.jpg",res27)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\61.jpg",res28)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\62.jpg",res29)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\63.jpg",res30)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\64.jpg",res31)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\65.jpg",res32)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\66.jpg",res33)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\67.jpg",res34)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\68.jpg",res35)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\69.jpg",res36)
    cv2.imshow('res', res1)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    break

# %%
  
     img28 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (28).jpg')
    img28 = cv2.resize(img28, (256, 256), interpolation=cv2.INTER_CUBIC)
    img29 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (29).jpg')
    img29 = cv2.resize(img29, (256, 256), interpolation=cv2.INTER_CUBIC)
    img30 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (30).jpg')
    img30 = cv2.resize(img30, (256, 256), interpolation=cv2.INTER_CUBIC)
    img31 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (31).jpg')
    img31 = cv2.resize(img31, (256, 256), interpolation=cv2.INTER_CUBIC)
    img32 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (32).jpg')
    img32 = cv2.resize(img32, (256, 256), interpolation=cv2.INTER_CUBIC)
    img33 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (33).jpg')
    img33 = cv2.resize(img33, (256, 256), interpolation=cv2.INTER_CUBIC)
    img34 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (34).jpg')
    img34 = cv2.resize(img34, (256, 256), interpolation=cv2.INTER_CUBIC)
    img35 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (35).jpg')
    img35 = cv2.resize(img35, (256, 256), interpolation=cv2.INTER_CUBIC)
    img36 = cv2.imread('C:\\Users\\dagne\\Desktop\\common_bean_rust\\1 (36).jpg')
    img36 = cv2.resize(img36, (256, 256), interpolation=cv2.INTER_CUBIC)
    
    
    
    
    
    
    
    # convert BGR to HSV
    imgHSV28 = cv2.cvtColor(img28, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV28, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res28 = cv2.bitwise_and(img28, img28, mask=mask)
    # convert BGR to HSV
    imgHSV29 = cv2.cvtColor(img29, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV29, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res29 = cv2.bitwise_and(img29, img29, mask=mask)
    # convert BGR to HSV
    imgHSV30 = cv2.cvtColor(img30, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV30, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res30 = cv2.bitwise_and(img30, img30, mask=mask)
    # convert BGR to HSV
    imgHSV31 = cv2.cvtColor(img31, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV31, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res31 = cv2.bitwise_and(img31, img31, mask=mask)
    # convert BGR to HSV
    imgHSV32 = cv2.cvtColor(img32, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV32, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res32 = cv2.bitwise_and(img32, img32, mask=mask)
    # convert BGR to HSV
    imgHSV33 = cv2.cvtColor(img33, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV33, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res33 = cv2.bitwise_and(img33, img33, mask=mask)
    # convert BGR to HSV
    imgHSV34 = cv2.cvtColor(img34, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV34, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res34 = cv2.bitwise_and(img34, img34, mask=mask)
    # convert BGR to HSV
    imgHSV35 = cv2.cvtColor(img35, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV35, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res35 = cv2.bitwise_and(img35, img35, mask=mask)
    # convert BGR to HSV
    imgHSV36 = cv2.cvtColor(img36, cv2.COLOR_RGB2HSV)
    # create the Mask
    mask = cv2.inRange(imgHSV36, low_green, high_green)
    # inverse mask
    mask = 255-mask
    res36 = cv2.bitwise_and(img36, img36, mask=mask)

    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\61.jpg",res28)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\62.jpg",res29)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\63.jpg",res30)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\64.jpg",res31)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\65.jpg",res32)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\66.jpg",res33)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\67.jpg",res34)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\68.jpg",res35)
    cv2.imwrite("C:\\Users\\dagne\\Desktop\\common_bean_rust\\69.jpg",res36)
# Out:
#   File "<ipython-input-5-b43b27503115>", line 2
#     img28 = cv2.resize(img28, (256, 256), interpolation=cv2.INTER_CUBIC)
#     ^
# IndentationError: unexpected indent
